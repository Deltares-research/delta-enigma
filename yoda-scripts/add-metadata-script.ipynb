# %% [markdown]
# ### Let's start by initializing the session

# %%
from ibridges.interactive import interactive_auth
session = interactive_auth() 
import warnings
warnings.filterwarnings('ignore')
# Note that at this point we are still using local machine, not Yoda (yet)
# make sure that you have a correct 'irods_environment.json' file in the .irods folder of your home directory

# %% [markdown]
# ### Check the session parameters

# %%
print(session.username)
print(session.default_resc) # the resource to which data will be uploaded
print(session.zone)
print(session.server_version)
print(session.get_user_info()) # lists user type and groups
print(session.home) #
# Out:
# jelle.vanmiltenburg@deltares.nl
# irodsResc
# deltaenigma
# (4, 2, 12)
# ('rodsuser', ['jelle.vanmiltenburg@deltares.nl', 'priv-category-add', 'priv-group-add', 'public', 'research-deltares', 'research-nioz', 'research-tno', 'research-tud', 'research-ut', 'research-uu', 'research-wur'])
# /deltaenigma/home

# %%
from ibridges.path import IrodsPath
from pathlib import Path

home = IrodsPath(session, '~/research-deltares/WP1/test')
irods_path = IrodsPath(session, home, 'new_research')
irods_col_path = irods_path / 'uploads'
irods_obj_path = irods_col_path / 'test.txt'
print("Current working location:", irods_path)
print("Demo collection name:", irods_col_path, "exists: ", irods_col_path.collection_exists())
print("Demo object name:", irods_obj_path, "exists: ", irods_obj_path.dataobject_exists())
# Out:
# Current working location: /deltaenigma/home/research-deltares/WP1/test/new_research
# Demo collection name: /deltaenigma/home/research-deltares/WP1/test/new_research/uploads exists:  True
# Demo object name: /deltaenigma/home/research-deltares/WP1/test/new_research/uploads/test.txt exists:  True

# %% [markdown]
# ### What is the current metadata associated with the data object?

# %%
irods_obj_path.meta
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 irods_obj_path.meta
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/ibridges/path.py:106, in IrodsPath.__getattribute__(self, attr)
#     104 if attr in ["parts"]:
#     105     return self._path.__getattribute__(attr)
# --> 106 return super().__getattribute__(attr)
#
# AttributeError: 'IrodsPath' object has no attribute 'meta'

# %%
print(irods_obj_path.meta)
obj_meta = irods_obj_path.meta
obj_meta.add('Key', 'Value', 'Units')
print(type(obj_meta))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(irods_obj_path.meta)
#       2 obj_meta = irods_obj_path.meta
#       3 obj_meta.add('Key', 'Value', 'Units')
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/ibridges/path.py:106, in IrodsPath.__getattribute__(self, attr)
#     104 if attr in ["parts"]:
#     105     return self._path.__getattribute__(attr)
# --> 106 return super().__getattribute__(attr)
#
# AttributeError: 'IrodsPath' object has no attribute 'meta'

# %%
print(ibridges.__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 ibridges.version
#
# NameError: name 'ibridges' is not defined

# %% [markdown]
# ## Add metadata

# %%
# more info: https://ibridges.readthedocs.io/en/latest/data_transfers.html#download
from ibridges import download
local_download_path = Path('downloads/')
download(session, irods_path, local_download_path)
# Out:
# 100%|██████████| 2.73k/2.73k [00:00<00:00, 6.40kB/s]
# {'create_dir': {'downloads/new_research'},
#  'create_collection': set(),
#  'upload': [],
#  'download': [(IrodsPath(/, deltaenigma, home, research-deltares, WP1, test, new_research, uploads, test.txt),
#    PosixPath('downloads/new_research/uploads/test.txt')),
#   (IrodsPath(/, deltaenigma, home, research-deltares, WP1, test, new_research, uploads, yoda-metadata.json),
#    PosixPath('downloads/new_research/uploads/yoda-metadata.json'))],
#  'resc_name': '',
#  'options': None}
